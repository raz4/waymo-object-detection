# %%
import tensorflow as tf
print("GPU Available: ", tf.test.is_gpu_available())

print("Tensorflow Version: ", tf.__version__)
print("Keras Version: ", tf.keras.__version__)

#check GPU
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print(physical_devices)
# Out:
# WARNING:tensorflow:From <ipython-input-1-184219fa7e9b>:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Available:  True
# Tensorflow Version:  2.4.0
# Keras Version:  2.4.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:4', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:5', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:6', device_type='GPU')]

# %%
# !nvidia-smi
# Out:
# Fri Apr  2 19:26:06 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.06    Driver Version: 450.51.06    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100S-PCI...  On   | 00000000:01:00.0 Off |                    0 |
# | N/A   41C    P0    41W / 250W |    467MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100S-PCI...  On   | 00000000:02:00.0 Off |                    0 |
# | N/A   41C    P0    41W / 250W |    465MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla V100S-PCI...  On   | 00000000:46:00.0 Off |                    0 |
# | N/A   40C    P0    38W / 250W |    465MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla V100S-PCI...  On   | 00000000:81:00.0 Off |                    0 |
# | N/A   41C    P0    38W / 250W |    465MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  Tesla V100S-PCI...  On   | 00000000:82:00.0 Off |                    0 |
# | N/A   41C    P0    37W / 250W |    465MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  Tesla V100S-PCI...  On   | 00000000:C1:00.0 Off |                    0 |
# | N/A   41C    P0    40W / 250W |    465MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  Tesla V100S-PCI...  On   | 00000000:C2:00.0 Off |                    0 |
# | N/A   41C    P0    41W / 250W |    465MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1800      G   /usr/lib/xorg/Xorg                  4MiB |
# |    0   N/A  N/A     15045      C   ...conda3/envs/tf/bin/python      457MiB |
# |    1   N/A  N/A      1800      G   /usr/lib/xorg/Xorg                  4MiB |
# |    1   N/A  N/A     15045      C   ...conda3/envs/tf/bin/python      457MiB |
# |    2   N/A  N/A      1800      G   /usr/lib/xorg/Xorg                  4MiB |
# |    2   N/A  N/A     15045      C   ...conda3/envs/tf/bin/python      457MiB |
# |    3   N/A  N/A      1800      G   /usr/lib/xorg/Xorg                  4MiB |
# |    3   N/A  N/A     15045      C   ...conda3/envs/tf/bin/python      457MiB |
# |    4   N/A  N/A      1800      G   /usr/lib/xorg/Xorg                  4MiB |
# |    4   N/A  N/A     15045      C   ...conda3/envs/tf/bin/python      457MiB |
# |    5   N/A  N/A      1800      G   /usr/lib/xorg/Xorg                  4MiB |
# |    5   N/A  N/A     15045      C   ...conda3/envs/tf/bin/python      457MiB |
# |    6   N/A  N/A      1800      G   /usr/lib/xorg/Xorg                  4MiB |
# |    6   N/A  N/A     15045      C   ...conda3/envs/tf/bin/python      457MiB |
# +-----------------------------------------------------------------------------+

# %%
import os
import pathlib

# Clone the tensorflow models repository if it doesn't already exist
if "models" in pathlib.Path.cwd().parts:
    while "models" in pathlib.Path.cwd().parts:
        os.chdir('..')
elif not pathlib.Path('models').exists():
    # !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 2578, done.
# remote: Counting objects: 100% (2578/2578), done.
# remote: Compressing objects: 100% (2150/2150), done.
# remote: Total 2578 (delta 640), reused 1263 (delta 396), pack-reused 0
# Receiving objects: 100% (2578/2578), 32.50 MiB | 3.83 MiB/s, done.
# Resolving deltas: 100% (640/640), done.

# %%
# Install the Object Detection API
# !cd models/research/ && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install .
# Out:
# Processing /home/xenowulf/code/waymo-object-detection/models/research
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
# Collecting apache-beam
#   Downloading apache_beam-2.28.0-cp37-cp37m-manylinux2010_x86_64.whl (9.0 MB)
#      |████████████████████████████████| 9.0 MB 6.1 MB/s eta 0:00:01
# Requirement already satisfied: pillow in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from object-detection==0.1) (8.2.0)
# Collecting lxml
#   Downloading lxml-4.6.3-cp37-cp37m-manylinux1_x86_64.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 10.2 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from object-detection==0.1) (3.4.1)
# Requirement already satisfied: Cython in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from object-detection==0.1) (0.29.22)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: tf-slim in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from object-detection==0.1) (2.0.2)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from object-detection==0.1) (1.6.2)
# Requirement already satisfied: pandas in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from object-detection==0.1) (1.1.5)
# Collecting tf-models-official
#   Downloading tf_models_official-2.4.0-py2.py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 11.4 MB/s eta 0:00:01
# Collecting fastavro<2,>=0.21.4
#   Downloading fastavro-1.3.5-cp37-cp37m-manylinux2014_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 11.0 MB/s eta 0:00:01
# Requirement already satisfied: mock<3.0.0,>=1.0.1 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from apache-beam->object-detection==0.1) (2.0.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: pytz>=2018.3 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from apache-beam->object-detection==0.1) (2021.1)
# Requirement already satisfied: future<1.0.0,>=0.18.2 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from apache-beam->object-detection==0.1) (0.18.2)
# Requirement already satisfied: typing-extensions<3.8.0,>=3.7.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from apache-beam->object-detection==0.1) (3.7.4.3)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from apache-beam->object-detection==0.1) (2.8.1)
# Collecting avro-python3
#   Downloading avro-python3-1.9.2.1.tar.gz (37 kB)
# Collecting pydot<2,>=1.2.0
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 10.8 MB/s eta 0:00:01
# Requirement already satisfied: protobuf<4,>=3.12.2 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from apache-beam->object-detection==0.1) (3.15.7)
# Requirement already satisfied: oauth2client<5,>=2.0.1 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from apache-beam->object-detection==0.1) (4.1.3)
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.11.3-cp37-cp37m-manylinux2014_x86_64.whl (512 kB)
#      |████████████████████████████████| 512 kB 11.7 MB/s eta 0:00:01
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from apache-beam->object-detection==0.1) (2.25.1)
# Collecting httplib2<0.18.0,>=0.8
#   Downloading httplib2-0.17.4-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 4.3 MB/s  eta 0:00:01
# Requirement already satisfied: grpcio<2,>=1.29.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from apache-beam->object-detection==0.1) (1.32.0)
# Collecting pyarrow<3.0.0,>=0.15.1
#   Downloading pyarrow-2.0.0-cp37-cp37m-manylinux2014_x86_64.whl (17.7 MB)
#      |████████████████████████████████| 17.7 MB 8.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy<1.20.0,>=1.14.3 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from apache-beam->object-detection==0.1) (1.19.5)
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.6.0-py3-none-any.whl (33 kB)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: pbr>=0.11 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from mock<3.0.0,>=1.0.1->apache-beam->object-detection==0.1) (5.5.1)
# Requirement already satisfied: pyasn1>=0.1.7 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from oauth2client<5,>=2.0.1->apache-beam->object-detection==0.1) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from oauth2client<5,>=2.0.1->apache-beam->object-detection==0.1) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from oauth2client<5,>=2.0.1->apache-beam->object-detection==0.1) (4.7.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from pydot<2,>=1.2.0->apache-beam->object-detection==0.1) (2.4.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.10)
# Requirement already satisfied: cycler>=0.10.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from lvis->object-detection==0.1) (0.10.0)
# Collecting opencv-python>=4.1.0.25
#   Downloading opencv_python-4.5.1.48-cp37-cp37m-manylinux2014_x86_64.whl (50.4 MB)
#      |████████████████████████████████| 50.4 MB 2.4 MB/s eta 0:00:012    |▌                               | 778 kB 10.8 MB/s eta 0:00:05
# Requirement already satisfied: kiwisolver>=1.1.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from lvis->object-detection==0.1) (1.3.1)
# Requirement already satisfied: setuptools>=18.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from pycocotools->object-detection==0.1) (52.0.0.post20210125)
# Requirement already satisfied: tensorflow>=2.4.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (2.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (5.4.1)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: psutil>=5.4.3 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (5.8.0)
# Requirement already satisfied: tensorflow-datasets in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (4.2.0)
# Requirement already satisfied: tensorflow-addons in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (0.12.1)
# Requirement already satisfied: sentencepiece in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (0.1.95)
# Requirement already satisfied: kaggle>=1.3.9 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (1.5.12)
# Requirement already satisfied: google-cloud-bigquery>=0.31.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (2.13.1)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (7.0.0)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (0.11.0)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (0.5.0)
# Requirement already satisfied: gin-config in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (0.4.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (2.1.0)
# Requirement already satisfied: seqeval in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (1.2.2)
# Requirement already satisfied: opencv-python-headless in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tf-models-official->object-detection==0.1) (4.5.1.48)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (1.26.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (3.0.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (0.1.0)
# Requirement already satisfied: google-auth<2dev,>=1.16.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (1.28.0)
# Requirement already satisfied: packaging>=14.3 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (20.9)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (1.53.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from google-auth<2dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official->object-detection==0.1) (4.2.1)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.4.1 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from google-cloud-bigquery>=0.31.0->tf-models-official->object-detection==0.1) (1.6.0)
# Requirement already satisfied: google-resumable-media<2.0dev,>=0.6.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from google-cloud-bigquery>=0.31.0->tf-models-official->object-detection==0.1) (1.2.0)
# Requirement already satisfied: proto-plus>=1.10.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from google-cloud-bigquery>=0.31.0->tf-models-official->object-detection==0.1) (1.18.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from google-resumable-media<2.0dev,>=0.6.0->google-cloud-bigquery>=0.31.0->tf-models-official->object-detection==0.1) (1.1.2)
# Requirement already satisfied: cffi>=1.0.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from google-crc32c<2.0dev,>=1.0->google-resumable-media<2.0dev,>=0.6.0->google-cloud-bigquery>=0.31.0->tf-models-official->object-detection==0.1) (1.14.5)
# Requirement already satisfied: pycparser in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from cffi>=1.0.0->google-crc32c<2.0dev,>=1.0->google-resumable-media<2.0dev,>=0.6.0->google-cloud-bigquery>=0.31.0->tf-models-official->object-detection==0.1) (2.20)
# Requirement already satisfied: tqdm in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from kaggle>=1.3.9->tf-models-official->object-detection==0.1) (4.59.0)
# Requirement already satisfied: python-slugify in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from kaggle>=1.3.9->tf-models-official->object-detection==0.1) (4.0.1)
# Requirement already satisfied: h5py~=2.10.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (2.10.0)
# Requirement already satisfied: google-pasta~=0.2 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (0.2.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (1.12)
# Requirement already satisfied: opt-einsum~=3.3.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (3.3.0)
# Requirement already satisfied: astunparse~=1.6.3 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (1.6.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (0.3.3)
# Requirement already satisfied: tensorboard~=2.4 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (2.4.1)
# Requirement already satisfied: wheel~=0.35 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (0.36.2)
# Requirement already satisfied: termcolor~=1.1.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (2.4.0)
# Requirement already satisfied: absl-py~=0.10 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (0.12.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (0.4.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (1.3.0)
# Requirement already satisfied: importlib-metadata in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (3.10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (3.1.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official->object-detection==0.1) (0.1.5)
# Requirement already satisfied: zipp>=0.5 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.4.0->tf-models-official->object-detection==0.1) (3.4.1)
# Requirement already satisfied: text-unidecode>=1.3 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official->object-detection==0.1) (1.3)
# Requirement already satisfied: scikit-learn>=0.21.3 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from seqeval->tf-models-official->object-detection==0.1) (0.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official->object-detection==0.1) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official->object-detection==0.1) (1.0.1)
# Requirement already satisfied: typeguard>=2.7 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow-addons->tf-models-official->object-detection==0.1) (2.12.0)
# Requirement already satisfied: attrs>=18.1.0 in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow-datasets->tf-models-official->object-detection==0.1) (20.3.0)
# Requirement already satisfied: promise in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow-datasets->tf-models-official->object-detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow-datasets->tf-models-official->object-detection==0.1) (0.29.0)
# Requirement already satisfied: importlib-resources in /home/xenowulf/anaconda3/envs/tf/lib/python3.7/site-packages (from tensorflow-datasets->tf-models-official->object-detection==0.1) (5.1.2)
# Building wheels for collected packages: object-detection, avro-python3, dill, docopt
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1643307 sha256=b10f335aa8d72b32a830865f3ea731b065b6eff6827942d838c510e786145540
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nzrr2hkg/wheels/39/fa/6e/938decad060df0d102a2e4dd4d24766fbd28b3239322fae5f3
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.9.2.1-py3-none-any.whl size=43512 sha256=cf27374340a7dbeb73ff3217f4683e4df9054d266ba0fd8858cafcc175385225
#   Stored in directory: /home/xenowulf/.cache/pip/wheels/bc/49/5f/fdb5b9d85055c478213e0158ac122b596816149a02d82e0ab1
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78532 sha256=def3f3381d1689e880b2e72f5701fe01225f2c9fdc4095743997cbeaadcea6af
#   Stored in directory: /home/xenowulf/.cache/pip/wheels/a4/61/fd/c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=fb113a57a5ae80dc66f799e0851ed2eebf6d2a985f80e664712da7f0c0e9e598
#   Stored in directory: /home/xenowulf/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
# Successfully built object-detection avro-python3 dill docopt
# Installing collected packages: httplib2, docopt, dill, pymongo, pydot, pyarrow, opencv-python, hdfs, fastavro, dataclasses, avro-python3, tf-models-official, lxml, lvis, contextlib2, apache-beam, object-detection
#   Attempting uninstall: httplib2
#     Found existing installation: httplib2 0.19.1
#     Uninstalling httplib2-0.19.1:
#       Successfully uninstalled httplib2-0.19.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.3
#     Uninstalling dill-0.3.3:
#       Successfully uninstalled dill-0.3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcs-oauth2-boto-plugin 2.7 requires httplib2>=0.18, but you have httplib2 0.17.4 which is incompatible.
# Successfully installed apache-beam-2.28.0 avro-python3-1.9.2.1 contextlib2-0.6.0.post1 dataclasses-0.6 dill-0.3.1.1 docopt-0.6.2 fastavro-1.3.5 hdfs-2.6.0 httplib2-0.17.4 lvis-0.5.3 lxml-4.6.3 object-detection-0.1 opencv-python-4.5.1.48 pyarrow-2.0.0 pydot-1.4.2 pymongo-3.11.3 tf-models-official-2.4.0

# %%
# !python ./models/research/object_detection/builders/model_builder_tf2_test.py
# Out:
# 2021-04-02 19:31:05.482786: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Running tests under Python 3.7.0: /home/xenowulf/anaconda3/envs/tf/bin/python
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model
# 2021-04-02 19:31:07.852605: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-02 19:31:07.853228: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-02 19:31:07.920298: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:07.921984: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:02:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:07.923634: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0000:46:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:07.925260: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0000:81:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:07.926900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 4 with properties:
# pciBusID: 0000:82:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:07.928537: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 5 with properties:
# pciBusID: 0000:c1:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:07.930168: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 6 with properties:
# pciBusID: 0000:c2:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:07.930183: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-02 19:31:07.931917: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-04-02 19:31:07.931953: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-04-02 19:31:07.932692: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-04-02 19:31:07.932856: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-04-02 19:31:07.934597: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-04-02 19:31:07.935005: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-04-02 19:31:07.935106: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-04-02 19:31:07.957896: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3, 4, 5, 6
# 2021-04-02 19:31:07.961250: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-02 19:31:08.741638: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:08.743355: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:02:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:08.744998: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0000:46:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:08.746682: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0000:81:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:08.748331: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 4 with properties:
# pciBusID: 0000:82:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:08.749956: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 5 with properties:
# pciBusID: 0000:c1:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:08.751617: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 6 with properties:
# pciBusID: 0000:c2:00.0 name: Tesla V100S-PCIE-32GB computeCapability: 7.0
# coreClock: 1.597GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 1.03TiB/s
# 2021-04-02 19:31:08.751643: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-02 19:31:08.751675: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-04-02 19:31:08.751687: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-04-02 19:31:08.751699: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-04-02 19:31:08.751710: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-04-02 19:31:08.751721: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-04-02 19:31:08.751731: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-04-02 19:31:08.751743: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-04-02 19:31:08.774426: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3, 4, 5, 6
# 2021-04-02 19:31:08.774469: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-02 19:31:11.243154: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-02 19:31:11.243199: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1 2 3 4 5 6
# 2021-04-02 19:31:11.243206: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N Y Y Y Y Y Y
# 2021-04-02 19:31:11.243210: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   Y N Y Y Y Y Y
# 2021-04-02 19:31:11.243214: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 2:   Y Y N Y Y Y Y
# 2021-04-02 19:31:11.243218: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 3:   Y Y Y N Y Y Y
# 2021-04-02 19:31:11.243223: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 4:   Y Y Y Y N Y Y
# 2021-04-02 19:31:11.243227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 5:   Y Y Y Y Y N Y
# 2021-04-02 19:31:11.243234: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 6:   Y Y Y Y Y Y N
# 2021-04-02 19:31:11.258124: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 29692 MB memory) -> physical GPU (device: 0, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:01:00.0, compute capability: 7.0)
# 2021-04-02 19:31:11.262089: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 29692 MB memory) -> physical GPU (device: 1, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:02:00.0, compute capability: 7.0)
# 2021-04-02 19:31:11.266013: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 29692 MB memory) -> physical GPU (device: 2, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:46:00.0, compute capability: 7.0)
# 2021-04-02 19:31:11.269873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 29692 MB memory) -> physical GPU (device: 3, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:81:00.0, compute capability: 7.0)
# 2021-04-02 19:31:11.273603: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:4 with 29692 MB memory) -> physical GPU (device: 4, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:82:00.0, compute capability: 7.0)
# 2021-04-02 19:31:11.277445: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:5 with 29692 MB memory) -> physical GPU (device: 5, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:c1:00.0, compute capability: 7.0)
# 2021-04-02 19:31:11.281169: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:6 with 29692 MB memory) -> physical GPU (device: 6, name: Tesla V100S-PCIE-32GB, pci bus id: 0000:c2:00.0, compute capability: 7.0)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model): 4.31s
# I0402 19:31:11.939481 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_create_center_net_model): 4.31s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.28s
# I0402 19:31:12.219770 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.28s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0402 19:31:12.220178 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I0402 19:31:12.241761 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# I0402 19:31:12.258513 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# I0402 19:31:12.275416 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.11s
# I0402 19:31:12.385907 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.11s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.11s
# I0402 19:31:12.494213 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.11s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.11s
# I0402 19:31:12.608526 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.11s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.11s
# I0402 19:31:12.721871 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.11s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.12s
# I0402 19:31:12.839991 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.12s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# I0402 19:31:12.874318 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0402 19:31:13.105483 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0402 19:31:13.105582 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 64
# I0402 19:31:13.105636 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 3
# I0402 19:31:13.182000 140331504514880 efficientnet_model.py:147] round_filter input=32 output=32
# I0402 19:31:13.195231 140331504514880 efficientnet_model.py:147] round_filter input=32 output=32
# I0402 19:31:13.195307 140331504514880 efficientnet_model.py:147] round_filter input=16 output=16
# I0402 19:31:13.236089 140331504514880 efficientnet_model.py:147] round_filter input=16 output=16
# I0402 19:31:13.236174 140331504514880 efficientnet_model.py:147] round_filter input=24 output=24
# I0402 19:31:13.339279 140331504514880 efficientnet_model.py:147] round_filter input=24 output=24
# I0402 19:31:13.339378 140331504514880 efficientnet_model.py:147] round_filter input=40 output=40
# I0402 19:31:13.440852 140331504514880 efficientnet_model.py:147] round_filter input=40 output=40
# I0402 19:31:13.440949 140331504514880 efficientnet_model.py:147] round_filter input=80 output=80
# I0402 19:31:13.592908 140331504514880 efficientnet_model.py:147] round_filter input=80 output=80
# I0402 19:31:13.593003 140331504514880 efficientnet_model.py:147] round_filter input=112 output=112
# I0402 19:31:13.745843 140331504514880 efficientnet_model.py:147] round_filter input=112 output=112
# I0402 19:31:13.745948 140331504514880 efficientnet_model.py:147] round_filter input=192 output=192
# I0402 19:31:13.950019 140331504514880 efficientnet_model.py:147] round_filter input=192 output=192
# I0402 19:31:13.950124 140331504514880 efficientnet_model.py:147] round_filter input=320 output=320
# I0402 19:31:13.998653 140331504514880 efficientnet_model.py:147] round_filter input=1280 output=1280
# I0402 19:31:14.017934 140331504514880 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0402 19:31:14.078184 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0402 19:31:14.078293 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 88
# I0402 19:31:14.078336 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 4
# I0402 19:31:14.081926 140331504514880 efficientnet_model.py:147] round_filter input=32 output=32
# I0402 19:31:14.092619 140331504514880 efficientnet_model.py:147] round_filter input=32 output=32
# I0402 19:31:14.092685 140331504514880 efficientnet_model.py:147] round_filter input=16 output=16
# I0402 19:31:14.174422 140331504514880 efficientnet_model.py:147] round_filter input=16 output=16
# I0402 19:31:14.174524 140331504514880 efficientnet_model.py:147] round_filter input=24 output=24
# I0402 19:31:14.326600 140331504514880 efficientnet_model.py:147] round_filter input=24 output=24
# I0402 19:31:14.326703 140331504514880 efficientnet_model.py:147] round_filter input=40 output=40
# I0402 19:31:14.478418 140331504514880 efficientnet_model.py:147] round_filter input=40 output=40
# I0402 19:31:14.478516 140331504514880 efficientnet_model.py:147] round_filter input=80 output=80
# I0402 19:31:14.681711 140331504514880 efficientnet_model.py:147] round_filter input=80 output=80
# I0402 19:31:14.681827 140331504514880 efficientnet_model.py:147] round_filter input=112 output=112
# I0402 19:31:14.885926 140331504514880 efficientnet_model.py:147] round_filter input=112 output=112
# I0402 19:31:14.886044 140331504514880 efficientnet_model.py:147] round_filter input=192 output=192
# I0402 19:31:15.142161 140331504514880 efficientnet_model.py:147] round_filter input=192 output=192
# I0402 19:31:15.142287 140331504514880 efficientnet_model.py:147] round_filter input=320 output=320
# I0402 19:31:15.241949 140331504514880 efficientnet_model.py:147] round_filter input=1280 output=1280
# I0402 19:31:15.261109 140331504514880 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0402 19:31:15.324719 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0402 19:31:15.324816 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 112
# I0402 19:31:15.324867 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 5
# I0402 19:31:15.328477 140331504514880 efficientnet_model.py:147] round_filter input=32 output=32
# I0402 19:31:15.339127 140331504514880 efficientnet_model.py:147] round_filter input=32 output=32
# I0402 19:31:15.339194 140331504514880 efficientnet_model.py:147] round_filter input=16 output=16
# I0402 19:31:15.523919 140331504514880 efficientnet_model.py:147] round_filter input=16 output=16
# I0402 19:31:15.524050 140331504514880 efficientnet_model.py:147] round_filter input=24 output=24
# I0402 19:31:15.677356 140331504514880 efficientnet_model.py:147] round_filter input=24 output=24
# I0402 19:31:15.677472 140331504514880 efficientnet_model.py:147] round_filter input=40 output=48
# I0402 19:31:15.830437 140331504514880 efficientnet_model.py:147] round_filter input=40 output=48
# I0402 19:31:15.830563 140331504514880 efficientnet_model.py:147] round_filter input=80 output=88
# I0402 19:31:16.036495 140331504514880 efficientnet_model.py:147] round_filter input=80 output=88
# I0402 19:31:16.036617 140331504514880 efficientnet_model.py:147] round_filter input=112 output=120
# I0402 19:31:16.241041 140331504514880 efficientnet_model.py:147] round_filter input=112 output=120
# I0402 19:31:16.241162 140331504514880 efficientnet_model.py:147] round_filter input=192 output=208
# I0402 19:31:16.502245 140331504514880 efficientnet_model.py:147] round_filter input=192 output=208
# I0402 19:31:16.502389 140331504514880 efficientnet_model.py:147] round_filter input=320 output=352
# I0402 19:31:16.606904 140331504514880 efficientnet_model.py:147] round_filter input=1280 output=1408
# I0402 19:31:16.625453 140331504514880 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0402 19:31:16.690708 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0402 19:31:16.690812 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 160
# I0402 19:31:16.690970 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 6
# I0402 19:31:16.694735 140331504514880 efficientnet_model.py:147] round_filter input=32 output=40
# I0402 19:31:16.706387 140331504514880 efficientnet_model.py:147] round_filter input=32 output=40
# I0402 19:31:16.706489 140331504514880 efficientnet_model.py:147] round_filter input=16 output=24
# I0402 19:31:16.791404 140331504514880 efficientnet_model.py:147] round_filter input=16 output=24
# I0402 19:31:16.791521 140331504514880 efficientnet_model.py:147] round_filter input=24 output=32
# I0402 19:31:16.946325 140331504514880 efficientnet_model.py:147] round_filter input=24 output=32
# I0402 19:31:16.946464 140331504514880 efficientnet_model.py:147] round_filter input=40 output=48
# I0402 19:31:17.102115 140331504514880 efficientnet_model.py:147] round_filter input=40 output=48
# I0402 19:31:17.102283 140331504514880 efficientnet_model.py:147] round_filter input=80 output=96
# I0402 19:31:17.362892 140331504514880 efficientnet_model.py:147] round_filter input=80 output=96
# I0402 19:31:17.363038 140331504514880 efficientnet_model.py:147] round_filter input=112 output=136
# I0402 19:31:17.623598 140331504514880 efficientnet_model.py:147] round_filter input=112 output=136
# I0402 19:31:17.623743 140331504514880 efficientnet_model.py:147] round_filter input=192 output=232
# I0402 19:31:17.934972 140331504514880 efficientnet_model.py:147] round_filter input=192 output=232
# I0402 19:31:17.935115 140331504514880 efficientnet_model.py:147] round_filter input=320 output=384
# I0402 19:31:18.035601 140331504514880 efficientnet_model.py:147] round_filter input=1280 output=1536
# I0402 19:31:18.055132 140331504514880 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0402 19:31:18.123546 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0402 19:31:18.123663 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 224
# I0402 19:31:18.123718 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 7
# I0402 19:31:18.127426 140331504514880 efficientnet_model.py:147] round_filter input=32 output=48
# I0402 19:31:18.138512 140331504514880 efficientnet_model.py:147] round_filter input=32 output=48
# I0402 19:31:18.138582 140331504514880 efficientnet_model.py:147] round_filter input=16 output=24
# I0402 19:31:18.356409 140331504514880 efficientnet_model.py:147] round_filter input=16 output=24
# I0402 19:31:18.356552 140331504514880 efficientnet_model.py:147] round_filter input=24 output=32
# I0402 19:31:18.561754 140331504514880 efficientnet_model.py:147] round_filter input=24 output=32
# I0402 19:31:18.561877 140331504514880 efficientnet_model.py:147] round_filter input=40 output=56
# I0402 19:31:18.765826 140331504514880 efficientnet_model.py:147] round_filter input=40 output=56
# I0402 19:31:18.765941 140331504514880 efficientnet_model.py:147] round_filter input=80 output=112
# I0402 19:31:19.072468 140331504514880 efficientnet_model.py:147] round_filter input=80 output=112
# I0402 19:31:19.072597 140331504514880 efficientnet_model.py:147] round_filter input=112 output=160
# I0402 19:31:19.381534 140331504514880 efficientnet_model.py:147] round_filter input=112 output=160
# I0402 19:31:19.381662 140331504514880 efficientnet_model.py:147] round_filter input=192 output=272
# I0402 19:31:19.791778 140331504514880 efficientnet_model.py:147] round_filter input=192 output=272
# I0402 19:31:19.791907 140331504514880 efficientnet_model.py:147] round_filter input=320 output=448
# I0402 19:31:19.892969 140331504514880 efficientnet_model.py:147] round_filter input=1280 output=1792
# I0402 19:31:19.911979 140331504514880 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0402 19:31:19.989363 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0402 19:31:19.989477 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 288
# I0402 19:31:19.989521 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 7
# I0402 19:31:19.993172 140331504514880 efficientnet_model.py:147] round_filter input=32 output=48
# I0402 19:31:20.004593 140331504514880 efficientnet_model.py:147] round_filter input=32 output=48
# I0402 19:31:20.004670 140331504514880 efficientnet_model.py:147] round_filter input=16 output=24
# I0402 19:31:20.127685 140331504514880 efficientnet_model.py:147] round_filter input=16 output=24
# I0402 19:31:20.127812 140331504514880 efficientnet_model.py:147] round_filter input=24 output=40
# I0402 19:31:20.385994 140331504514880 efficientnet_model.py:147] round_filter input=24 output=40
# I0402 19:31:20.386126 140331504514880 efficientnet_model.py:147] round_filter input=40 output=64
# I0402 19:31:20.643114 140331504514880 efficientnet_model.py:147] round_filter input=40 output=64
# I0402 19:31:20.643241 140331504514880 efficientnet_model.py:147] round_filter input=80 output=128
# I0402 19:31:21.130257 140331504514880 efficientnet_model.py:147] round_filter input=80 output=128
# I0402 19:31:21.130397 140331504514880 efficientnet_model.py:147] round_filter input=112 output=176
# I0402 19:31:21.492402 140331504514880 efficientnet_model.py:147] round_filter input=112 output=176
# I0402 19:31:21.492537 140331504514880 efficientnet_model.py:147] round_filter input=192 output=304
# I0402 19:31:21.956196 140331504514880 efficientnet_model.py:147] round_filter input=192 output=304
# I0402 19:31:21.956331 140331504514880 efficientnet_model.py:147] round_filter input=320 output=512
# I0402 19:31:22.109844 140331504514880 efficientnet_model.py:147] round_filter input=1280 output=2048
# I0402 19:31:22.128184 140331504514880 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0402 19:31:22.215365 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0402 19:31:22.215492 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 384
# I0402 19:31:22.215536 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 8
# I0402 19:31:22.219198 140331504514880 efficientnet_model.py:147] round_filter input=32 output=56
# I0402 19:31:22.230281 140331504514880 efficientnet_model.py:147] round_filter input=32 output=56
# I0402 19:31:22.230347 140331504514880 efficientnet_model.py:147] round_filter input=16 output=32
# I0402 19:31:22.353753 140331504514880 efficientnet_model.py:147] round_filter input=16 output=32
# I0402 19:31:22.353874 140331504514880 efficientnet_model.py:147] round_filter input=24 output=40
# I0402 19:31:22.661705 140331504514880 efficientnet_model.py:147] round_filter input=24 output=40
# I0402 19:31:22.661839 140331504514880 efficientnet_model.py:147] round_filter input=40 output=72
# I0402 19:31:22.967991 140331504514880 efficientnet_model.py:147] round_filter input=40 output=72
# I0402 19:31:22.968104 140331504514880 efficientnet_model.py:147] round_filter input=80 output=144
# I0402 19:31:23.378726 140331504514880 efficientnet_model.py:147] round_filter input=80 output=144
# I0402 19:31:23.378860 140331504514880 efficientnet_model.py:147] round_filter input=112 output=200
# I0402 19:31:23.788480 140331504514880 efficientnet_model.py:147] round_filter input=112 output=200
# I0402 19:31:23.788601 140331504514880 efficientnet_model.py:147] round_filter input=192 output=344
# I0402 19:31:24.504982 140331504514880 efficientnet_model.py:147] round_filter input=192 output=344
# I0402 19:31:24.505107 140331504514880 efficientnet_model.py:147] round_filter input=320 output=576
# I0402 19:31:24.659328 140331504514880 efficientnet_model.py:147] round_filter input=1280 output=2304
# I0402 19:31:24.677818 140331504514880 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0402 19:31:24.775526 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0402 19:31:24.775650 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 384
# I0402 19:31:24.775705 140331504514880 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 8
# I0402 19:31:24.779333 140331504514880 efficientnet_model.py:147] round_filter input=32 output=64
# I0402 19:31:24.790402 140331504514880 efficientnet_model.py:147] round_filter input=32 output=64
# I0402 19:31:24.790477 140331504514880 efficientnet_model.py:147] round_filter input=16 output=32
# I0402 19:31:24.957473 140331504514880 efficientnet_model.py:147] round_filter input=16 output=32
# I0402 19:31:24.957605 140331504514880 efficientnet_model.py:147] round_filter input=24 output=48
# I0402 19:31:25.320464 140331504514880 efficientnet_model.py:147] round_filter input=24 output=48
# I0402 19:31:25.320599 140331504514880 efficientnet_model.py:147] round_filter input=40 output=80
# I0402 19:31:25.679547 140331504514880 efficientnet_model.py:147] round_filter input=40 output=80
# I0402 19:31:25.679680 140331504514880 efficientnet_model.py:147] round_filter input=80 output=160
# I0402 19:31:26.197566 140331504514880 efficientnet_model.py:147] round_filter input=80 output=160
# I0402 19:31:26.197699 140331504514880 efficientnet_model.py:147] round_filter input=112 output=224
# I0402 19:31:26.711498 140331504514880 efficientnet_model.py:147] round_filter input=112 output=224
# I0402 19:31:26.711643 140331504514880 efficientnet_model.py:147] round_filter input=192 output=384
# I0402 19:31:27.544459 140331504514880 efficientnet_model.py:147] round_filter input=192 output=384
# I0402 19:31:27.544592 140331504514880 efficientnet_model.py:147] round_filter input=320 output=640
# I0402 19:31:27.756895 140331504514880 efficientnet_model.py:147] round_filter input=1280 output=2560
# I0402 19:31:27.775628 140331504514880 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 15.01s
# I0402 19:31:27.885213 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 15.01s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0402 19:31:27.892188 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0402 19:31:27.893564 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0402 19:31:27.893878 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0402 19:31:27.895082 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0402 19:31:27.896152 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0402 19:31:27.896407 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0402 19:31:27.897200 140331504514880 test_util.py:2076] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 21 tests in 20.263s
#
# OK (skipped=1)
